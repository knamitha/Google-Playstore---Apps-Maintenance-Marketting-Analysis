# %% [markdown]
# # Importing all the useful libraries for the project

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 

import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# Version of the Kernel Being Used
# Python 3.10.2
# 📚 Libraries Used
# This project makes use of popular Python libraries for data analysis and visualization:
#
# Python Badge NumPy Badge Pandas Badge Matplotlib Badge Seaborn Badge Skimpy Badge
#
# Python : The primary programming language.
# NumPy : For numerical computations.
# Pandas : For data manipulation and cleaning.
# Matplotlib : For static visualizations.
# Seaborn: For creating insightful statistical visualizations.
# Skimpy: For Descriptive statistics (optional).
# Warnings : For filter warnings.

# %% [markdown]
# # seaborn color used FIRST

# %%
sns.color_palette("GnBu")
# Out:
# [(0.8682814302191465, 0.9488811995386389, 0.8476585928489042),
#  (0.7590311418685122, 0.9056362937331796, 0.7543406382160708),
#  (0.5847750865051903, 0.8386928104575164, 0.7344867358708189),
#  (0.37993079584775086, 0.7430988081507113, 0.8027681660899654),
#  (0.2084582852748943, 0.5934025374855825, 0.7689965397923876),
#  (0.04913494809688582, 0.4261130334486736, 0.6836447520184545)]

# %% [markdown]
# # seaborn color used SECOND

# %%
sns.color_palette("viridis")
# Out:
# [(0.275191, 0.194905, 0.496005),
#  (0.212395, 0.359683, 0.55171),
#  (0.153364, 0.497, 0.557724),
#  (0.122312, 0.633153, 0.530398),
#  (0.288921, 0.758394, 0.428426),
#  (0.626579, 0.854645, 0.223353)]

# %% [raw]
# # About Dataset📑
# # Description
# # The Data Set was downloaded from Kaggle, from the following link
#
# # Context While numerous public datasets contain Apple App Store information, equivalent datasets for Google Play Store apps are relatively scarce. Upon closer investigation, I discovered that the iTunes App Store provides a well-structured, index-like appendix that makes web scraping straightforward. In contrast, the Google Play Store relies on modern techniques like dynamic content loading with JQuery, which makes scraping considerably more difficult.
#
# # Content Each app (row) has values for catergory, rating, size, price, installs and many more columns .
#
# # Acknowledgements This information is scraped from the Google Play Store.
#
# # Inspiration The Play Store apps data has enormous potential to drive app-making businesses to success. the information from the data help within various ways for the BI and other sectors to improve

# %% [markdown]
# # Importing Dataset

# %%
df=pd.read_csv("Google-Playstore.csv")
df.head()
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
# 1            5000.0              7662  True    0.0  ...
# 2              50.0                58  True    0.0  ...
# 3              10.0                19  True    0.0  ...
# 4             100.0               478  True    0.0  ...
#
#                   Developer Website              Developer Email  \
# 0       https://beniyizibyose.tk/#/       jean21101999@gmail.com
# 1   https://webserveis.netlify.app/         webserveis@gmail.com
# 2                               NaN          vnacrewit@gmail.com
# 3  http://www.climatesmarttech.com/  climatesmarttech2@gmail.com
# 4       http://www.horodyski.com.pl    rmilekhorodyski@gmail.com
#
#        Released  Last Updated Content Rating  \
# 0  Feb 26, 2020  Feb 26, 2020       Everyone
# 1  May 21, 2020  May 06, 2021       Everyone
# 2   Aug 9, 2019  Aug 19, 2019       Everyone
# 3  Sep 10, 2018  Oct 13, 2018       Everyone
# 4  Feb 21, 2020  Nov 12, 2018       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/        False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/         True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...        False
# 3                                                NaN         True
# 4                        http://www.horodyski.com.pl        False
#
#   In App Purchases Editors Choice         Scraped Time
# 0            False          False  2021-06-15 20:19:35
# 1            False          False  2021-06-15 20:19:35
# 2            False          False  2021-06-15 20:19:35
# 3            False          False  2021-06-15 20:19:35
# 4            False          False  2021-06-15 20:19:35
#
# [5 rows x 24 columns]

# %%
df_clean=df.copy()

# %% [markdown]
# # Analysing for data cleaning

# %%
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
#cheking the shape of the data
print(f'Total number of Rows in the dataset is: {df.shape[0]}')
print(f'Total number of Columns in the dataset is: {df.shape[1]}')
# Out:
# Total number of Rows in the dataset is: 2312944
# Total number of Columns in the dataset is: 24

# %%
#checking the size of the data 
print(f"The size of the data is : ",df.size)
# Out:
# The size of the data is :  55510656

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe(include="all")
# Out:
#            App Name                     App Id   Category        Rating  \
# count       2312939                    2312944    2312944  2.290061e+06
# unique      2177943                    2312944         48           NaN
# top     Tic Tac Toe  com.yyazilim.biliyormusun  Education           NaN
# freq            382                          1     241090           NaN
# mean            NaN                        NaN        NaN  2.203152e+00
# std             NaN                        NaN        NaN  2.106223e+00
# min             NaN                        NaN        NaN  0.000000e+00
# 25%             NaN                        NaN        NaN  0.000000e+00
# 50%             NaN                        NaN        NaN  2.900000e+00
# 75%             NaN                        NaN        NaN  4.300000e+00
# max             NaN                        NaN        NaN  5.000000e+00
#
#         Rating Count Installs  Minimum Installs  Maximum Installs     Free  \
# count   2.290061e+06  2312837      2.312837e+06      2.312944e+06  2312944
# unique           NaN       22               NaN               NaN        2
# top              NaN     100+               NaN               NaN     True
# freq             NaN   443368               NaN               NaN  2267876
# mean    2.864839e+03      NaN      1.834452e+05      3.202017e+05      NaN
# std     2.121626e+05      NaN      1.513144e+07      2.355495e+07      NaN
# min     0.000000e+00      NaN      0.000000e+00      0.000000e+00      NaN
# 25%     0.000000e+00      NaN      5.000000e+01      8.400000e+01      NaN
# 50%     6.000000e+00      NaN      5.000000e+02      6.950000e+02      NaN
# 75%     4.200000e+01      NaN      5.000000e+03      7.354000e+03      NaN
# max     1.385576e+08      NaN      1.000000e+10      1.205763e+10      NaN
#
#                Price  ...          Developer Website       Developer Email  \
# count   2.312944e+06  ...                    1552109               2312913
# unique           NaN  ...                     810440                950456
# top              NaN  ...  http://www.subsplash.com/  support@classplus.co
# freq             NaN  ...                       7519                 10345
# mean    1.034992e-01  ...                        NaN                   NaN
# std     2.633127e+00  ...                        NaN                   NaN
# min     0.000000e+00  ...                        NaN                   NaN
# 25%     0.000000e+00  ...                        NaN                   NaN
# 50%     0.000000e+00  ...                        NaN                   NaN
# 75%     0.000000e+00  ...                        NaN                   NaN
# max     4.000000e+02  ...                        NaN                   NaN
#
#             Released  Last Updated Content Rating  \
# count        2241891       2312944        2312944
# unique          4158          3918              6
# top     Jun 16, 2020  Jun 10, 2021       Everyone
# freq            2051         11186        2022089
# mean             NaN           NaN            NaN
# std              NaN           NaN            NaN
# min              NaN           NaN            NaN
# 25%              NaN           NaN            NaN
# 50%              NaN           NaN            NaN
# 75%              NaN           NaN            NaN
# max              NaN           NaN            NaN
#
#                                 Privacy Policy Ad Supported In App Purchases  \
# count                                  1891991      2312944          2312944
# unique                                  977743            2                2
# top     http://www.subsplash.com/legal/privacy        False            False
# freq                                      7481      1162170          2117635
# mean                                       NaN          NaN              NaN
# std                                        NaN          NaN              NaN
# min                                        NaN          NaN              NaN
# 25%                                        NaN          NaN              NaN
# 50%                                        NaN          NaN              NaN
# 75%                                        NaN          NaN              NaN
# max                                        NaN          NaN              NaN
#
#        Editors Choice         Scraped Time
# count         2312944              2312944
# unique              2                67374
# top             False  2021-06-16 06:31:44
# freq          2312091                   56
# mean              NaN                  NaN
# std               NaN                  NaN
# min               NaN                  NaN
# 25%               NaN                  NaN
# 50%               NaN                  NaN
# 75%               NaN                  NaN
# max               NaN                  NaN
#
# [11 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2312944 entries, 0 to 2312943
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   App Name           object
#  1   App Id             object
#  2   Category           object
#  3   Rating             float64
#  4   Rating Count       float64
#  5   Installs           object
#  6   Minimum Installs   float64
#  7   Maximum Installs   int64
#  8   Free               bool
#  9   Price              float64
#  10  Currency           object
#  11  Size               object
#  12  Minimum Android    object
#  13  Developer Id       object
#  14  Developer Website  object
#  15  Developer Email    object
#  16  Released           object
#  17  Last Updated       object
#  18  Content Rating     object
#  19  Privacy Policy     object
#  20  Ad Supported       bool
#  21  In App Purchases   bool
#  22  Editors Choice     bool
#  23  Scraped Time       object
# dtypes: bool(4), float64(4), int64(1), object(15)
# memory usage: 361.8+ MB

# %%
#cheking the null values from the data 
df.isnull().head()
# Out:
#    App Name  App Id  Category  Rating  Rating Count  Installs  \
# 0     False   False     False   False         False     False
# 1     False   False     False   False         False     False
# 2     False   False     False   False         False     False
# 3     False   False     False   False         False     False
# 4     False   False     False   False         False     False
#
#    Minimum Installs  Maximum Installs   Free  Price  ...  Developer Website  \
# 0             False             False  False  False  ...              False
# 1             False             False  False  False  ...              False
# 2             False             False  False  False  ...               True
# 3             False             False  False  False  ...              False
# 4             False             False  False  False  ...              False
#
#    Developer Email  Released  Last Updated  Content Rating  Privacy Policy  \
# 0            False     False         False           False           False
# 1            False     False         False           False           False
# 2            False     False         False           False           False
# 3            False     False         False           False            True
# 4            False     False         False           False           False
#
#    Ad Supported  In App Purchases  Editors Choice  Scraped Time
# 0         False             False           False         False
# 1         False             False           False         False
# 2         False             False           False         False
# 3         False             False           False         False
# 4         False             False           False         False
#
# [5 rows x 24 columns]

# %%
# unique values from the data 
df.nunique()
# Out:
# App Name             2177943
# App Id               2312944
# Category                  48
# Rating                    42
# Rating Count           38482
# Installs                  22
# Minimum Installs          22
# Maximum Installs      251563
# Free                       2
# Price                   1063
# Currency                  15
# Size                    1657
# Minimum Android          154
# Developer Id          758371
# Developer Website     810440
# Developer Email       950456
# Released                4158
# Last Updated            3918
# Content Rating             6
# Privacy Policy        977743
# Ad Supported               2
# In App Purchases           2
# Editors Choice             2
# Scraped Time           67374
# dtype: int64

# %% [markdown]
# # 📊 Dataset Overview: Observation_1 🩺

# %% [raw]
# 📊 Dataset Overview: Observation_1 🩺
# | 🏷️ Key Metric | 📝 Description & Insight | | :--- | :--- | | Total Rows (Records) | 2,312,944 | This is a massive dataset, confirming readiness for large-scale analysis. 🚀 | | Total Columns (Features)| 24 | The dataset has a diverse feature set available for analysis. ✨ | | Primary Data Issue | Missing Values are present across various columns and will be addressed in a subsequent cleaning step. 🧹 | | Data Type Fix Needed | Two vital columns are incorrectly stored as object (text) and must be converted to numeric types: Size and Installs. 🔢 |

# %% [markdown]
# # Cheking for NANs

# %%
#sorting the null values in order 
df.isnull().sum().sort_values(ascending=False)
# Out:
# Developer Website    760835
# Privacy Policy       420953
# Released              71053
# Rating                22883
# Rating Count          22883
# Minimum Android        6530
# Size                    196
# Currency                135
# Minimum Installs        107
# Installs                107
# Developer Id             33
# Developer Email          31
# App Name                  5
# Maximum Installs          0
# App Id                    0
# Category                  0
# Price                     0
# Free                      0
# Last Updated              0
# Content Rating            0
# Ad Supported              0
# In App Purchases          0
# Editors Choice            0
# Scraped Time              0
# dtype: int64

# %%
#NULL 
print(f"The total number of Null values in data frame : ",df.isnull().sum().sum())
# Out:
# The total number of Null values in data frame :  1305751

# %% [markdown]
# # Plotting NAN Values

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.figure(figsize=(20, 8))
# -------------------------------------------------------------------
ax1 = plt.subplot(1, 2, 1) 
N_val = df.isnull().sum() / len(df) * 100

# ---  Generate Colors  ---
norm = plt.Normalize(N_val.min(), N_val.max())
cmap = plt.colormaps['GnBu'] 
colors = cmap(norm(N_val.values))

#plotting horizontal bar graph
N_val.plot(kind='barh', orientation="horizontal", ax=ax1,color=colors)
ax1.grid(axis='x', linestyle='--', alpha=0.7) 
# ⭐ ALIGNMENT FIX: Move plt.text to ax1.text() and adjust coordinates.
text = f"""The null values in the data are highest at few 
             • Developer website 32.99%
             • Privacy Policy 18.20%
             • Released 3.17%
             • And few more with less then 0.1%"""
ax1.text(#(x=0.95, y=0.95) are now relative to ax1
    0.95, 0.95, 
    text, 
    fontsize=9, 
    color='#555',
    transform=ax1.transAxes, 
    bbox=dict(boxstyle="round,pad=0.4", facecolor='white', alpha=0.5, edgecolor='#ccc'),
    verticalalignment='top', 
    horizontalalignment='right')
ax1.set_title("Total percentage of null values from the data", pad=20, fontsize=16, fontweight="bold")
ax1.set_xlabel("Percentage",fontsize=12) 
ax1.set_ylabel("Columns")              
# -------------------------------------------------------------------
ax2 = plt.subplot(1, 2, 2) 
sample_size = 1000 
df_sample = df.isnull().sample(n=sample_size, replace=False, random_state=42)
sns.heatmap(
    df_sample, 
    cmap="viridis",
    yticklabels=False,
    cbar_kws={'label':'Missing Values'},
    ax=ax2)
ax2.set_title("Missing Values Heatmap", pad=20, fontsize=16, fontweight="bold")
ax2.set_xlabel('Columns', fontsize=12)
# ⭐ SPACING FIX: Use subplots_adjust to add horizontal space (wspace)
plt.subplots_adjust(wspace=0.15) 
plt.figtext(0.95, 0.01, 'Rashmi sharma .', fontsize=8, color='#000000', style='italic',
             verticalalignment='bottom', horizontalalignment='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5)) # make figure size
norm = plt.Normalize(N_val.min(), N_val.max())
cmap = plt.colormaps['GnBu'] 
colors = cmap(norm(N_val.values))
N_val[N_val < 1].plot(kind='bar',color=colors,edgecolor="black",linewidth=0.2,linestyle="--") # plot the null values by their percentage in each column
plt.xlabel('Columns') # add the x-axis labels
plt.ylabel('Percentage') # add the labels for y-axis
plt.title('less than one percent of missing values')  # add the title for the plot
plt.figtext(0.95, 0.01, 'Rashmi sharma .', fontsize=8, color='#000000', style='italic',
             verticalalignment='bottom', horizontalalignment='right')
plt.tight_layout()
plt.show()

# %%
# length of Data "NOW" 
print(f" Length of Data  : :{len(df)}")
# Out:
#  Length of Data  : :2312944

# %% [markdown]
# # DEALING WITH HIGHEST NaN

# %% [markdown]
# # 📊 Dataset Overview: Observation_2 🧹 Missing Values

# %% [raw]
# # 🕳️ Missing Values Summary
# # Your dataset contains NaN values across multiple columns, which can affect model performance and distort exploratory analysis.
#
# # 🏷️ Column	❗ Missing Values	🔍 Insight
# # Example: Developer website	32.9%	Significant missing values — needs careful imputation or removal.
# # Privacy Policy	18.1%	contains so much missing data interrupts in final data.
# # Released	3.0%	Released date is not provided for many entries.
# # Rating and rating_count	1.0%	Missing rating and ratring counts.
# # Minium android	0.28%	Missing androids.
# # Iinstalls, minimum installs, currency	0.1%	Minimum missing values.
# # Other features	All < 0.1%	Nulls.
# # ⚠️ Final numbers will depend on your .isna().sum() output in the EDA code cell.

# %%
# percentage of null values in each column 
#length is defining the row of the data 
(df.isnull().sum()/len(df)*100).sort_values(ascending=False)
# Out:
# Developer Website    32.894657
# Privacy Policy       18.199879
# Released              3.071972
# Rating                0.989345
# Rating Count          0.989345
# Minimum Android       0.282324
# Size                  0.008474
# Currency              0.005837
# Minimum Installs      0.004626
# Installs              0.004626
# Developer Id          0.001427
# Developer Email       0.001340
# App Name              0.000216
# Maximum Installs      0.000000
# App Id                0.000000
# Category              0.000000
# Price                 0.000000
# Free                  0.000000
# Last Updated          0.000000
# Content Rating        0.000000
# Ad Supported          0.000000
# In App Purchases      0.000000
# Editors Choice        0.000000
# Scraped Time          0.000000
# dtype: float64

# %% [raw]
# # Dropping the NAN values from the data
# df.dropna(subset=['installs','minimum_installs','currency','developer_email', 'editors_choice', 'in_app_purchases', 'ad_supported', 'content_rating','last_updated','scraped_time','developer_id','size','price','free','maximum_installs','category','app_id','app_name'], inplace=True)

# %%
# length after removing null values
print(f"Length of the dataframe after removing null values: {len(df)}")
# Out:
# Length of the dataframe after removing null values: 2312944

# %% [markdown]
# # Dropping Developer_website and Privacy_policy

# %%
# removing the column 
remove=['Developer Website','Privacy Policy']
pd.set_option('display.max_columns', None)
df.drop(columns=remove, axis=1, inplace=True)
df.head()
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price Currency  Size  \
# 0              10.0                15  True    0.0      USD   10M
# 1            5000.0              7662  True    0.0      USD  2.9M
# 2              50.0                58  True    0.0      USD  3.7M
# 3              10.0                19  True    0.0      USD  1.8M
# 4             100.0               478  True    0.0      USD  6.2M
#
#   Minimum Android                       Developer Id  \
# 0      7.1 and up  Jean Confident Irénée NIYIZIBYOSE
# 1      5.0 and up                         Webserveis
# 2    4.0.3 and up                         Cabin Crew
# 3    4.0.3 and up                Climate Smart Tech2
# 4      4.1 and up              Rafal Milek-Horodyski
#
#                Developer Email      Released  Last Updated Content Rating  \
# 0       jean21101999@gmail.com  Feb 26, 2020  Feb 26, 2020       Everyone
# 1         webserveis@gmail.com  May 21, 2020  May 06, 2021       Everyone
# 2          vnacrewit@gmail.com   Aug 9, 2019  Aug 19, 2019       Everyone
# 3  climatesmarttech2@gmail.com  Sep 10, 2018  Oct 13, 2018       Everyone
# 4    rmilekhorodyski@gmail.com  Feb 21, 2020  Nov 12, 2018       Everyone
#
#    Ad Supported  In App Purchases  Editors Choice         Scraped Time
# 0         False             False           False  2021-06-15 20:19:35
# 1          True             False           False  2021-06-15 20:19:35
# 2         False             False           False  2021-06-15 20:19:35
# 3          True             False           False  2021-06-15 20:19:35
# 4         False             False           False  2021-06-15 20:19:35

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Released            71053
# Rating Count        22883
# Rating              22883
# Minimum Android      6530
# Size                  196
# Currency              135
# Minimum Installs      107
# Installs              107
# Developer Id           33
# Developer Email        31
# App Name                5
# App Id                  0
# Category                0
# Price                   0
# Free                    0
# Maximum Installs        0
# Last Updated            0
# Content Rating          0
# Ad Supported            0
# In App Purchases        0
# Editors Choice          0
# Scraped Time            0
# dtype: int64

# %% [markdown]
# <!-- # Dealing with Released -->

# %% [markdown]
# Dealing with Released

# %%
# Option A: use last_updated (if available)
df['Released'] = pd.to_datetime(df['Released'], errors='coerce')
df['Last Updated'] = pd.to_datetime(df['Last Updated'], errors='coerce')
df['Released'] = df['Released'].fillna(df['Last Updated'])

# Option B: fill with mode (most common release date)
""" fillin_rel=df['Released'].mode()
df['Released'] = df['Released'].fillna(fillin_rel) """
# Out:
# " fillin_rel=df['Released'].mode()\ndf['Released'] = df['Released'].fillna(fillin_rel) "

# %% [markdown]
# Dealing with Ratings

# %%
# Adjusting the rating and rating counts as median 
filling_rating=df['Rating'].median()
df['Rating']=df['Rating'].fillna(filling_rating)

# %% [markdown]
# Dealing with Rating count

# %%
filling_rating_count=df['Rating Count'].median()
df['Rating Count']=df['Rating Count'].fillna(filling_rating_count)

# %% [markdown]
# Dealing with MIN Android

# %%
#the values are not that much so just droping them yeahhh!
df.dropna(subset=['Minimum Android'],inplace=True)

# %%
#cheking the null values again
df.isnull().sum()
#As we can see we have cleared all the missing values and nan values
# Out:
# App Name              5
# App Id                0
# Category              0
# Rating                0
# Rating Count          0
# Installs            107
# Minimum Installs    107
# Maximum Installs      0
# Free                  0
# Price                 0
# Currency            135
# Size                196
# Minimum Android       0
# Developer Id         33
# Developer Email      31
# Released              0
# Last Updated          0
# Content Rating        0
# Ad Supported          0
# In App Purchases      0
# Editors Choice        0
# Scraped Time          0
# dtype: int64

# %% [markdown]
# # Duplicated Values

# %% [raw]
# Duplicates can skew statistical measures such as mean, median, and standard deviation, and can also lead to over-representation of certain data points. important part of data wrangling process

# %%
#checking if there are any duplicated in the dataset rows  
#in bool
df.duplicated().any()
# Out:
# np.False_

# %%
#in numeric base 
print('Sum of all the duplicate row in the dataset' ,df.duplicated().sum())
# Out:
# Sum of all the duplicate row in the dataset 0

# %%
#finding duplicat if any in the "App_name" column
print("Total Duplicated in the App_columns",df['App Name'].duplicated().sum())
# Out:
# Total Duplicated in the App_columns 134592

# %% [markdown]
# # 📊 Dataset Overview: Observation_3 🔁 Duplicate Values

# %% [raw]
# 🔍 Duplicate Records Check
# During EDA, duplicate rows were found in the dataset — mainly caused by:
#
# Apps listed multiple times
# Same app with identical metadata
# Multiple entries from Play Store scrapes
# | Metric | Value | Insight | | :--- | :--- | :--- | | Total Duplicate Rows Found | 0 | (Replace 0 with your actual .duplicated().sum() output) | | Duplicates Removed | 0 | Ensures no repetition biases the analysis. | | We have 0 duplicates in the dataset, which is great news! 🎉 |

# %%
df['App Id'].value_counts().head(10)
# Out:
# App Id
# com.yyazilim.biliyormusun                        1
# com.ishakwe.gakondo                              1
# com.webserveis.batteryinfo                       1
# com.doantiepvien.crm                             1
# cst.stJoseph.ug17ucs548                          1
# com.horodyski.grower                             1
# com.imocci                                       1
# getfreedata.superfatiza.unlimitedjiodataprank    1
# com.mozaix.simoneboard                           1
# com.whatsopen.app                                1
# Name: count, dtype: int64

# %%
df['App Id'].value_counts().sum()
# Out:
# np.int64(2306414)

# %%
# app id is same to the total number of rows in the column with diff column values 
df.shape[0]
# Out:
# 2306414

# %% [markdown]
# Dealing with Size

# %%
print("total missing value in the size colums : ",df['Size'].isnull().sum())
# Out:
# total missing value in the size colums :  196

# %%
#lets have a look on the size column 
print("Unique values in the size columns : ",df['Size'].unique())
# Out:
# Unique values in the size columns :  ['10M' '2.9M' '3.7M' ... '405M' '3.2k' '512M']

# %% [markdown]
# # Renaming size column to size_in_bytes

# %%
#it is imp to rename the col name because we change the values in bytes
df.rename(columns={'Size':'size in bytes'},inplace=True)

# %%
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'size in bytes', 'Minimum Android', 'Developer Id', 'Developer Email',
#        'Released', 'Last Updated', 'Content Rating', 'Ad Supported',
#        'In App Purchases', 'Editors Choice', 'Scraped Time'],
#       dtype='object')

# %% [markdown]
# Dealing with content Writing

# %%
# Change 'content_Rating' to 'content_rating'

df['Content Rating'] = df['Content Rating'].replace('Unrated',"Everyone")

# Cleaning other values just to include Everyone, Teens and Adult 

df['Content Rating'] = df['Content Rating'].replace('Mature 17+',"Adults")
df['Content Rating'] = df['Content Rating'].replace('Adults only 18+',"Adults")
df['Content Rating'] = df['Content Rating'].replace('Everyone 10+',"Everyone")

# %%
# content rating value counts
df['Content Rating'].value_counts()
# Out:
# Content Rating
# Everyone    2050137
# Teen         196005
# Adults        60272
# Name: count, dtype: int64

# %% [markdown]
# Dealing with Installs

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 100+               442177
# 1,000+             397262
# 10+                298833
# 10,000+            256306
# 500+               188587
# 50+                169972
# 5,000+             143341
# 100,000+           110101
# 50,000+             75241
# 5+                  73331
# 1+                  64815
# 1,000,000+          33597
# 500,000+            26988
# 0+                  11503
# 5,000,000+           6585
# 10,000,000+          6171
# 50,000,000+           823
# 100,000,000+          540
# 500,000,000+           65
# 1,000,000,000+         54
# 5,000,000,000+         14
# 10,000,000,000+         1
# Name: count, dtype: int64

# %%
#Changing the installs from object to numeric 

df['Installs'] = df['Installs'].str.replace(',', '', regex=False)
df['Installs'] = df['Installs'].str.replace('+', '', regex=False)
df['Installs'] = df['Installs'].str.replace('Free', '0', regex=False)
df['Installs'] = pd.to_numeric(df['Installs'])
df['Installs'].dtype
# Out:
# dtype('float64')

# %%
#Total values in install column
print("Total sum of thr value_counts in installs",df['Installs'].value_counts().sum())
# Out:
# Total sum of thr value_counts in installs 2306307

# %%
#cheking the min and mx installs from installs 

print(f'The Maximum value in the installs column is : {df['Installs'].max()}')
print(f'The Minimum value in the installs column is : {df['Installs'].min()}')
# Out:
# The Maximum value in the installs column is : 10000000000.0
# The Minimum value in the installs column is : 0.0

# %% [markdown]
# NEW COLUMN Install_Category

# %%
# making a new column called 'Installs_category' which will have the category of the installs
bins = [-1, 0, 10, 1000, 10000, 100000, 1000000, 10000000, 10000000000]
labels=['no', 'Very low', 'Low', 'Moderate', 'More than moderate', 'High', 'Very High', 'Top Notch']
df['installs_category'] = pd.cut(df['Installs'], bins=bins, labels=labels)

# %%
df['installs_category'].value_counts()
# Out:
# installs_category
# Low                   1197998
# Very low               436979
# Moderate               399647
# More than moderate     185342
# High                    60585
# Very High               12756
# no                      11503
# Top Notch                1497
# Name: count, dtype: int64

# %% [markdown]
# Dealing with free

# %%
# price value counts 
print("Apps that have Price = 0, have Free column True")
df.loc[(df.Price==0) & (df.Free==False),'Free'] = True
print(df.Free.value_counts())
# Out:
# Apps that have Price = 0, have Free column True
# Free
# True     2261759
# False      44655
# Name: count, dtype: int64

# %%
print(f'The Total number of unique value in price column is {df["Price"].nunique()}')
print(f'The number of unique value in price column is {df["Price"].unique()}')
# Out:
# The Total number of unique value in price column is 1061
# The number of unique value in price column is [ 0.        1.99      4.99     ...  3.041816 26.746362 18.903596]

# %% [markdown]
# # New column type dropping free

# %%
#creating a new column which based on type "Free"or"Paid"
df['Type']=df['Free'].apply(lambda x:'free' if x else 'paid')

#Dropping the Free column
df.drop(columns=['Free'],inplace=True)

# %%
#count the occurences of each app type 
app_type_count=df['Type'].value_counts()
print("App Type distribution: ")
for app_type, count in app_type_count.items():
    print(f"{app_type}:{count} apps")
# Out:
# App Type distribution:
# free:2261759 apps
# paid:44655 apps

# %%
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Price', 'Currency',
#        'size in bytes', 'Minimum Android', 'Developer Id', 'Developer Email',
#        'Released', 'Last Updated', 'Content Rating', 'Ad Supported',
#        'In App Purchases', 'Editors Choice', 'Scraped Time',
#        'installs_category', 'Type'],
#       dtype='object')

# %% [markdown]
# Checking Min Installs

# %%
#minimum installs 
print(f"The total number of unique value in minimum_installs column is {df['Minimum Installs'].nunique()}")
# Out:
# The total number of unique value in minimum_installs column is 22

# %% [markdown]
# Checking Max Installs

# %%
#maximum installs 
print(f"The total number of unique value in maximum_installs column is {df['Maximum Installs'].nunique()}")
# Out:
# The total number of unique value in maximum_installs column is 251306

# %% [markdown]
# Checking Realesed

# %%
print(f'The Total number of unique value in released column is {df["Released"].nunique()}')
# Out:
# The Total number of unique value in released column is 4171

# %% [markdown]
# Checking Ratings

# %%
print(f'The Total number of unique value in rating column is {df["Rating"].nunique()}')
print(f'The number of unique value in rating column is {df["Rating"].unique()}')
# Out:
# The Total number of unique value in rating column is 42
# The number of unique value in rating column is [0.  4.4 5.  4.5 2.  4.7 4.9 3.9 3.7 4.2 3.4 3.8 4.6 4.1 2.5 2.3 2.1 2.7
#  4.3 3.1 4.8 3.3 4.  2.4 3.2 3.6 2.6 2.9 1.5 3.5 1.3 2.8 3.  2.2 1.8 1.2
#  1.9 1.7 1.4 1.6 1.  1.1]

# %% [markdown]
# Checking Rating Count

# %%
print(f'The Total number of unique value in rating column is {df["Rating Count"].nunique()}')
print(f'The number of unique value in rating column is {df["Rating Count"].unique()}')
# Out:
# The Total number of unique value in rating column is 38451
# The number of unique value in rating column is [0.0000e+00 6.4000e+01 5.0000e+00 ... 8.7553e+04 7.5960e+04 7.8351e+04]

# %% [markdown]
# # DATA VISUALIZATION

# %%
df['Category'].value_counts().head(10)
# Out:
# Category
# Education            240548
# Music & Audio        154698
# Tools                143379
# Business             143249
# Entertainment        137978
# Lifestyle            118155
# Books & Reference    116584
# Personalization       88983
# Health & Fitness      83252
# Productivity          79302
# Name: count, dtype: int64

# %% [raw]
# Which Category has the highest number of apps ?

# %%
top_categories=df['Category'].value_counts().head(10)
plt.figure(figsize=(10,5))
plt.grid(axis='y', linestyle='--', alpha=0.7)
sns.barplot(data=top_categories,palette='GnBu')
plt.xlabel("Categories",fontsize=12)
plt.ylabel("Number of apps ", fontsize=12)
plt.xticks(rotation=45,ha='right')
plt.tight_layout()
plt.show()

# %% [raw]
# Top 5 Categories with Ratings ?

# %%
# Top 5 categories by number of apps
top5_categories = df['Category'].value_counts().head(5).index

# Calculate average rating for these categories
avg_rating_cat = df[df['Category'].isin(top5_categories)].groupby('Category')['Rating'].mean().sort_values(ascending=False)

plt.figure(figsize=(10,5))
ax = sns.barplot(x=avg_rating_cat.index, y=avg_rating_cat.values, palette="GnBu")

plt.title("Average Ratings of Top 5 Most Popular Categories", fontsize=16)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.xticks(rotation=45, ha='right')

# Display rating values on top of bars
for p in ax.patches:
    ax.annotate(f"{p.get_height():.2f}",
                (p.get_x() + p.get_width()/2, p.get_height()),
                ha='center', va='bottom', fontsize=11)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [raw]
# Visualizing top 5 App Names with Ratings

# %%
# -------- STEP 1: Select Top 5 Categories by Number of Apps (value_counts) --------
top5_categories = df['Category'].value_counts().head(5).index

# -------- STEP 2: Filter only those categories --------
df_top = df[df['Category'].isin(top5_categories)]

# -------- STEP 3: Get Top 5 apps (by installs) inside those categories --------
top_apps_per_category = (
    df_top.sort_values('Installs', ascending=False)
          .groupby('Category')
          .head(5)
)

# -------- STEP 4: Plot Horizontal Subplots --------
fig, axes = plt.subplots(5, 1, figsize=(18, 25))
sns.set(style="whitegrid")

for i, category in enumerate(top5_categories):
    data = top_apps_per_category[top_apps_per_category['Category'] == category]
    
    sns.barplot(
        y='App Name',
        x='Installs',
        data=data,
        ax=axes[i],
        palette="viridis"
    )
    
    axes[i].set_title(f"{i+1}. {category} — Top 5 Apps by Installs", fontsize=16)
    axes[i].set_xlabel("Installs", fontsize=13)
    axes[i].set_ylabel("App Name", fontsize=13)
    
    # ---- Annotate ratings on bars ----
    for p, rating in zip(axes[i].patches, data['Rating']):
        width = p.get_width()
        axes[i].text(
            width + width * 0.01,
            p.get_y() + p.get_height() / 2,
            f"Rating: {rating:.2f}",
            va='center', fontsize=11, fontweight='bold'
        )

plt.tight_layout(pad=2.5)
fig.suptitle("Top 5 Categories (Highest Number of Apps) → Top 5 Apps per Category\nRatings Annotated Horizontally",
             fontsize=20, y=1.04)
plt.show()

# %% [raw]
# Which category has the highest average rating?

# %%
#calculate the average rating for each category
df.groupby('Category')['Rating'].mean().sort_values(ascending=False).head(10)
# Out:
# Category
# Role Playing               3.371214
# Casino                     3.279506
# Simulation                 3.205928
# Weather                    3.121102
# Card                       3.087852
# Racing                     2.961082
# Video Players & Editors    2.904680
# Word                       2.902716
# Strategy                   2.886406
# Comics                     2.869888
# Name: Rating, dtype: float64

# %%
average_rating=df.groupby('Category')['Rating'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(10,5))
sns.barplot(data=average_rating,palette='GnBu')
plt.title("Top 10 categories with the highest average ratings",fontsize=14)
plt.xlabel("Categories",fontsize=14)
plt.ylabel("Average Rating",fontsize=14)
plt.xticks(rotation=45,ha='right')
plt.ylim(0,5)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [raw]
# No Of Content Rating Free Vs Paid ?

# %%
plt.figure(figsize=(10,10))
ax = sns.countplot(x='Content Rating', hue='Type', data=df, palette="viridis")
plt.title("Content rating in free and paid", fontsize=22)

for p in ax.patches:
    height = p.get_height()
    ax.annotate(height, (p.get_x() + p.get_width() / 2, height),
                ha='center', va='bottom', fontsize=14)

plt.xlabel("Content Rating", fontsize=18)
plt.ylabel("Count", fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
# Top 5 Free + Top 5 Paid apps sorted by highest installs 
top_free = df[df['Type'] == 'Free'].sort_values(by='Installs', ascending=False).head(5)
top_paid = df[df['Type'] == 'Paid'].sort_values(by='Installs', ascending=False).head(5)

# Combine both
top_apps = pd.concat([top_free, top_paid])

# Pivot table (ONLY data table — NO plot)
pivot_table = top_apps.pivot_table(
    index='App Name',
    columns='Type',
    values='Rating',
    fill_value=0)

pivot_table
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [raw]
# Which category has highest no og installs?

# %%
df.groupby('Category')['Installs'].sum().sort_values(ascending=False).head(10)
# Out:
# Category
# Tools                      6.988024e+10
# Communication              4.298429e+10
# Productivity               2.821168e+10
# Photography                1.895127e+10
# Video Players & Editors    1.858893e+10
# Action                     1.739623e+10
# Social                     1.716558e+10
# Entertainment              1.709604e+10
# Casual                     1.683643e+10
# Arcade                     1.449842e+10
# Name: Installs, dtype: float64

# %%
category_installs = df.groupby('Category')['Installs'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,5))
sns.barplot(x=category_installs.values, y=category_installs.index,palette='GnBu')

plt.xlabel("Total Installs")
plt.ylabel("Category")
plt.title("Top 10 categories by number of installs")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [raw]
# Analyse the influence of content rating in install volume ?

# %%
df['Content Rating'].value_counts()
# Out:
# Content Rating
# Everyone    2050137
# Teen         196005
# Adults        60272
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16, 6)) # make figure size
sns.barplot(x='Content Rating', y='Installs', data=df,palette="GnBu")
# Out:
# <Axes: xlabel='Content Rating', ylabel='Installs'>

# %% [raw]
# Which type has highest no of Installs ?

# %%
plt.figure(figsize=(18,18))
ax = sns.countplot(data =df, x='Installs',hue='Type',palette="GnBu");
plt.title("Number of Installs in different Types ", fontsize=22, fontweight='bold')
plt.xlabel("Installs", fontsize=22, fontweight='bold')
plt.ylabel("Count", fontsize=22, fontweight='bold')
plt.legend(title='Type', fontsize=18, title_fontsize=20, markerscale=2)
plt.xticks(fontsize=10,fontweight='bold',rotation=45,ha='right')
plt.figtext(0.95, 0.01, 'Rashmi sharma .', fontsize=12, color='#000000', style='italic',
             verticalalignment='bottom', horizontalalignment='right')
plt.tight_layout()
plt.show()

# %% [raw]
# What is the Top 5 Free Apps with highest number of Reviews ?

# %%
plt.figure(figsize=(16, 6)) # make figure size
# sns.barplot(x='App Name', y='Rating Count', data=df[df['Type'] == 'Free'].sort_values(by='Rating Count', ascending=False).head(5),palette="viridis") # plot th
# plt.grid(axis='y', linestyle='--', alpha=1)

# %% [raw]
# what is the top 5 paid apps with highest no of reviews ?

# %%
plt.figure(figsize=(16, 6)) # make figure size
# sns.barplot(x='App Name', y='Rating Count', data=df[df['Type'] == 'Paid'].sort_values(by='Rating Count', ascending=False).head(5),palette="GnBu")
# plt.grid(axis='y', linestyle='--', alpha=1)

# %% [markdown]
# # 📊 Google Play Store App Analysis: Project Plan

# %% [raw]
# This document provides a structured, question-by-question plan for analyzing the Google Play Store dataset. Each section includes a ready-to-use HTML header for your Jupyter Markdown cells and a specific, impactful graph suggestion

# %% [markdown]
# Category: Which Category Has the Highest Number of Apps? 🌐

# %% [raw]
# Analysis: The Education category has the highest number of apps, with 240,526

# %% [markdown]
# Rating: Top 5 Categories with Highest Ratings ⭐

# %% [raw]
# Analysis: Sorting top 5 categories from the category relies under average(mean) relies between 2.5 to 1.5 ratings and the top one is Entertainment with 2.44 rating

# %% [markdown]
# Visualizing Top 5 Apps in Each Category by Ratings 🏆

# %% [raw]
# Analysis: Top 5 applications category with Top 5 ratings with them Education get the highest rating 4.30with the highest number of category in this range

# %% [markdown]
# Which Category Has the Highest Average Rating? 🌟

# %% [raw]
# Analysis: Calculate the mean rating per category to measure user satisfaction the data of mean relies under 3.3 to 2.8 and the top category is Role Playing .

# %% [markdown]
# Number of Content Rating Free vs Paid Apps 🔍

# %% [raw]
# Analysis: Content rating according to the type of app, Everyone category from the type column got the highest rating with free : 2008275.0 and paid : 41538.0 rest category are below .25 content ratings

# %% [markdown]
# Installs: Which Category Has the Highest Number of Installs? 📈

# %% [raw]
# Analysis: According to Sum of the total installs per category to understand top ones are Tools, Communication, Productivity, Photography, Video Players & Editors

# %% [markdown]
# Top 5 PAID Apps with Highest Number of Reviews 💎

# %% [raw]
# Analysis: The top 5 paid apps with the highest number of reviews are Minecraft has the highest number of reviews in the dataset and is popular among users

# %% [markdown]
#                                                               #THANK YOU
